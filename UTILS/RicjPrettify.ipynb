# %% [markdown]
# # Prettyfier code
#
# 1. Use this code to make the code pretty.
# 2. Thid is using [`RICH`](https://github.com/Textualize/rich)
# 3. Copy code below into each new cell in the beginning
# 4. Main Documentation - This is the recommended docs - [`Rich Intro`](https://calmcode.io/course/rich/introduction)
# 6. Main [`REPO`](https://github.com/Textualize/rich)
# 7. Code below was made after several tries in an eariler worl
# 8. Practical Examples - [`RealPython`](https://realpython.com/python-rich-package/)

# %%
# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
console = Console() # Standard code to access console
# -------------------------------------------------------

# %%
# Test Rich 
console.print("""
              Centered Text - mistress fart
              in mouth and nose
              """, style="bold", justify="center")
# Out:
#
#                                                   Centered Text - mistress fart
#                                                         in mouth and nose

# %%
panel = Panel("""
Enjoy StinlySmellySWeaty women
""",title="Mistress",subtitle="ToiletSlave", style="Italic", border_style="magenta")
# Print the Panel
console.print(panel)
# Out:
# ╭─────────────────────────────────────────────────── Mistress ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Enjoy StinlySmellySWeaty women                                                                                  │
# │                                                                                                                 │
# ╰────────────────────────────────────────────────── ToiletSlave ──────────────────────────────────────────────────╯
