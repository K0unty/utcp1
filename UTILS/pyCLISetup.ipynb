# %% [markdown]
# <img src="https://i.postimg.cc/Vk6KLFNt/image.png" width="10%">
#
# # CLI Setup
#
# 1. Add the following line to make the py executable from cli

# %% [markdown]
# ## Add at start of the file
#
# ```sh
# #!/usr/bin/env python3
# ```
#
# then
# 1. Smell her farts
#
# ```sh
# > chmod +x liqpussy,py
# > ./liqpussy.py
# ```

# %% [markdown]
# # Add code at top of the PY file

# %%
#!/usr/bin/env python3
# Testing python files 

# Printing in console 

# Defining Colors
RED = "\033[1;31m"
GREEN = "\033[1;32m"
BLUE = "\033[1;34m"
RESET = "\033[0m"

print(f"""
      {RED}

Make .py file executable add
#!/usr/bin/env python3
      
▀██▀─▄███▄─▀██─██▀██▀▀█
─██─███─███─██─██─██▄█
─██─▀██▄██▀─▀█▄█▀─██▀█
▄██▄▄█▀▀▀─────▀──▄██▄▄█

      {RESET}
      """)
# Out:
#
#
# Make .py file executable add
# #!/usr/bin/env python3
#
# ▀██▀─▄███▄─▀██─██▀██▀▀█
# ─██─███─███─██─██─██▄█
# ─██─▀██▄██▀─▀█▄█▀─██▀█
# ▄██▄▄█▀▀▀─────▀──▄██▄▄█
