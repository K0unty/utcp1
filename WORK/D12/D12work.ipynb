# %% [markdown]
# <div style="background: url(https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExOGRjeTcweXZsYWltaGluZDhrNXJ2MXJxa285OHZtdzN4bmpmM3J0ZCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/rgzOwma0qMbM3x7Fqi/giphy.webp) repeat; color: #00ff00; padding: 2px; text-align: center;background-size: cover; text-shadow: 00 0 20px #ec4899">
#     <h1>Day 12 - Beginner - Scope And Number Guessing</h1>
#
# </div>
#
# 1. [`Colors`](https://rich.readthedocs.io/en/latest/appendix/colors.html?highlight=colors) _ list of standard colors that can be printed out
# 2. [`Ascii Banne Generator`](https://manytools.org/hacker-tools/ascii-banner/) - Used this to generate nice banners below
# 3. [`AsciiFlow`](https://asciiflow.com/#/) - Draw ASCII digrams you can then use this

# %% [markdown]
# <div style="background-color: #000502; color: #16a34a; padding: 10px; border-radius: 5px; font-size: 25px; text-align:center">
#   <a class="anchor" id="toc" style="text-decoration: none;">Table of Contents</a>
# </div>
#
# - ### [Lesson Summary](#s0)
# - ### [118 - Namespaces: Local Vs Global Scope](#s118)
# - ### [119 - BlockScope](#s119)
# - ### [120 - How to Modify a Global Variable](#s120)
# - ### [121 - Constants and GlobalScope](#s121)
# - ### [123 - The Number Guessing Game](#s121)

# %%
# Prettifyer code

# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
from rich.style import Style # For styles colors
from rich.text import Text # For text Styles
console = Console() # Standard code to access console
# -------------------------------------------------------

# %%
from rich.traceback import install
install()

# %% [markdown]
# # Lesson Summary <a class="anchor" id="s0"></a> [↩️TOC](#toc)
#
# 1. Focus is on understanding scope

# %% [markdown]
# # 118 - Namespaces: Local Vs Global Scope <a class="anchor" id="s118"></a> [↩️TOC](#toc)

# %%
# Code for scope 

enemies = 1 

def increase_enemies():
    enemies = 2
    enemies += 1
    rprint(enemies)

increase_enemies()
rprint(f'Enemies outside function {enemies}')

# %%
# Local Scope 

def drink_potion():
    potion_strength = 2
    rprint(potion_strength)

drink_potion()
rprint(potion_strength)

# %%
# Global Scope
player_health = 20 

def drink_potion2():
    potion_strength = 3
    rprint(potion_strength)
    rprint(player_health)

drink_potion2()

# %% [markdown]
# 1. When you define a varibale its called namespace
# 3.

# %%
# Scope test
player_health2 = 40

def game():
    def drink_potion3():
        potion_strength3 = 3
        rprint(player_health2)
        
drink_potion()
rprint(player_health2)

# %% [markdown]
# # 119 - Block Scope <a class="anchor" id="s119"></a> [↩️TOC](#toc)

# %% [markdown]
# 1. No such thing has blockscope

# %%
# scope 
game_level = 3

def create_enemy():
    enemies = ["skeleton", "zombies", "alien"]
    if game_level < 5:
        new_enemy = enemies[0]
    
    rprint(new_enemy)

create_enemy()

# %% [markdown]
# # 120 - How to Modify a Global Variable <a class="anchor" id="s120"></a> [↩️TOC](#toc)

# %%
# Modifying the global scope

ene = 1

def inc_ene():
    
    # Changing the global var
    global ene
    
    ene += 1
    rprint(f'ene inside func: {ene}')

inc_ene()
rprint(f'ene outside func: {ene}')

# %% [markdown]
# 1. Using return statements

# %%
# Modifying the global scope

ene2 = 1

def inc_ene2():
    return ene2 + 100

ene2 = inc_ene2()
rprint(f'ene outside func: {ene2}')

# %% [markdown]
# # 121 - Constants and GlobalScope <a class="anchor" id="s121"></a> [↩️TOC](#toc)

# %%
# Global Constatnst - never Change 

PUSSY = 69 

def calc():
    rprint(PUSSY)
calc()

# %% [markdown]
# # 123 - The Number Guessing Game <a class="anchor" id="s123"></a> [↩️TOC](#toc)

# %% [markdown]
# 1. Advice on doing this project

# %%
banner = '''
**********************************************************
GUESS PUSSY SMELL - GUESS PUSSY SMELL - GUESS PUSSY SMELL
GUESS PUSSY SMELL - GUESS PUSSY SMELL - GUESS PUSSY SMELL
GUESS PUSSY SMELL - GUESS PUSSY SMELL - GUESS PUSSY SMELL
***********************************************************
'''

# Choosing a random number 1 to 100 

from random import randint as rp

# Global Constant for choosing level difficulty 
EA_LE = 10 
HA_LE = 5

turns = 0


# make function to compare guessed number for chosen number 
def check_answer(guess, answer, turns):
    """ 
    - Checks guess against random number
    - Returns the number of turns
    """
    if guess > answer:
        rprint(f'[#ff0000]😡 TOO HIGH')
        return turns - 1
    elif guess < answer :
        rprint(f'[#ff00d7]😡 TOO LOW')
        return turns - 1
    else: 
        rprint(f'[#d7ff00]👄 StinkIsRight {answer}')

        
# Make Function to set a difficulty 
def set_difficulty():
    level = Prompt.ask('Easy(E) or Hard(H) Fukr ?:', choices = ["E", "H"])
    if level == "E":
        return EA_LE
    else:
        return HA_LE
        

#  Make game function 

def game():
    rprint(f'''
    [#ff5f00]{banner}
    Smell her stink!!!

    ''')
    rprint(f'''Guess strenght of pussy stink from 1 to 100''')
    answer = rp(1,100)
    rprint(f'Expected - {answer}')

    turns = set_difficulty()

    guess = 0
    
    while guess != answer:
        rprint(f'You have {turns} Attempts')
        guess = int(Prompt.ask("Guess Number: "))
        
        # Tracks the number of turns 
        turns = check_answer(guess, answer, turns)
        if turns == 0:
            rprint(f'[red] ❌FUCKED ! NO TURNS LEFT❌')
            return

# Call game function 
game()
# Out:
#
# **********************************************************
# GUESS PUSSY SMELL - GUESS PUSSY SMELL - GUESS PUSSY SMELL
# GUESS PUSSY SMELL - GUESS PUSSY SMELL - GUESS PUSSY SMELL
# GUESS PUSSY SMELL - GUESS PUSSY SMELL - GUESS PUSSY SMELL
# ***********************************************************
#
#     Smell her stink!!!
# Guess strenght of pussy stink from 1 to 100
# Expected - 82
# Easy(E) or Hard(H) Fukr ?: [E/H]:
#  82
# Please select one of the available options
# Easy(E) or Hard(H) Fukr ?: [E/H]:
#  H
# You have 5 Attempts
# Guess Number: :
#  82
# 👄 StinkIsRight 82
