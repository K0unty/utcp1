# %% [markdown]
# <div style="background: url(https://media2.giphy.com/media/q9Hk9PiFxSN0yYsVqb/200w.webp?cid=ecf05e47zub0504u0k3kvfq98ujtenvf61gc2yg0jq24f9df&ep=v1_gifs_related&rid=200w.webp&ct=g) repeat; color: #00ff00; padding: 2px; text-align: center;background-size: cover; text-shadow: 00 0 20px #ec4899">
#     <h1>Day 13 - Beginner - Debugging - Finding Fixing Bugs</h1>
#
# </div>
#
# 1. [`Colors`](https://rich.readthedocs.io/en/latest/appendix/colors.html?highlight=colors) _ list of standard colors that can be printed out
# 2. [`Ascii Banne Generator`](https://manytools.org/hacker-tools/ascii-banner/) - Used this to generate nice banners below
# 3. [`AsciiFlow`](https://asciiflow.com/#/) - Draw ASCII digrams you can then use this

# %% [markdown]
# <div style="background-color: #000502; color: #16a34a; padding: 10px; border-radius: 5px; font-size: 25px; text-align:center">
#   <a class="anchor" id="toc" style="text-decoration: none;">Table of Contents</a>
# </div>
#
# - ### [Lesson Summary](#s0)
# - ### [125 - Describe the Problem](#s1)

# %%
# Prettifyer code

# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
from rich.style import Style # For styles colors
from rich.text import Text # For text Styles
console = Console() # Standard code to access console
from rich.traceback import install
install(show_locals=True)
# -------------------------------------------------------
# Out:
# <bound method InteractiveShell.excepthook of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x799b191d6680>>

# %% [markdown]
# # Lesson Summary <a class="anchor" id="s0"></a> [↩️TOC](#toc)

# %% [markdown]
# > This focuses on identifying bugs in python code via examples

# %% [markdown]
# # 125 - Describe the Problem <a class="anchor" id="s1"></a> [↩️TOC](#toc)

# %% [markdown]
# 1. In this code the `range` function goes up to `19`, so `L5` is never reached.
# 2. Important to understand what the code functions are actually doing.

# %%
# 1st code block 
def myfunc():
    for i in range(1,20):
        if i == 19:
            rprint(f'{i} = SniffHerAss')

# Run Function
myfunc()
# Out:
# 19 = SniffHerAss

# %% [markdown]
# 1. Sometimes the code will go out of range
# 2. The issue is wiht the random

# %%
# Random Dice Problem 
from random import randint as ri 

dice_imgs = ["①","②","③","④","⑤"]
dice_num = ri(1,5)

rprint(f' Random int generated - {dice_num}')

for i in range(0,20):
    dice_num = ri(1,6)
    rprint(f'Turn Number {i}')
    rprint(dice_imgs[dice_num])
# Out:
#  Random int generated - 5
# Turn Number 0
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:12                                                                                   │
# │                                                                                                  │
# │    9 for i in range(0,20):                                                                       │
# │   10 │   dice_num = ri(1,6)                                                                      │
# │   11 │   rprint(f'Turn Number {i}')                                                              │
# │ ❱ 12 │   rprint(dice_imgs[dice_num])                                                             │
# │   13                                                                                             │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │         box = <module 'rich.box' from '/opt/conda/lib/python3.10/site-packages/rich/box.py'> │ │
# │ │     Console = <class 'rich.console.Console'>                                                 │ │
# │ │     console = <console width=115 ColorSystem.TRUECOLOR>                                      │ │
# │ │   dice_imgs = ['①', '②', '③', '④', '⑤']                                                      │ │
# │ │    dice_num = 6                                                                              │ │
# │ │        exit = <IPython.core.autocall.ZMQExitAutocall object at 0x799b191d7400>               │ │
# │ │ get_ipython = <bound method InteractiveShell.get_ipython of                                  │ │
# │ │               <ipykernel.zmqshell.ZMQInteractiveShell object at 0x799b191d6680>>             │ │
# │ │           i = 0                                                                              │ │
# │ │          In = [                                                                              │ │
# │ │               │   '',                                                                        │ │
# │ │               │   '# Prettifyer code\n\n#                                                    │ │
# │ │               ------------------------------------------------------\nfrom'+636,             │ │
# │ │               │   '# 1st code block \ndef myfunc():\n    for i in range(1,20):\n        if   │ │
# │ │               == 20:\n    '+54,                                                              │ │
# │ │               │   '# 1st code block \ndef myfunc():\n    for i in range(1,20):\n        if i │ │
# │ │               == 20:\n  '+56,                                                                │ │
# │ │               │   '# 1st code block \ndef myfunc():\n    for i in range(1,20):\n        if i │ │
# │ │               == 19:\n  '+56,                                                                │ │
# │ │               │   '# 1st code block \ndef myfunc():\n    for i in range(1,20):\n        if i │ │
# │ │               == 19:\n  '+63,                                                                │ │
# │ │               │   '# Random Dice Problem \nfrom random import randint as ri \n\ndice_imgs =  │ │
# │ │               ["①",\u202f"②",'+78,                                                           │ │
# │ │               │   '# Random Dice Problem \nfrom random import randint as ri \n\ndice_imgs =  │ │
# │ │               ["①","②","'+77,                                                                │ │
# │ │               │   '# Random Dice Problem \nfrom random import randint as ri \n\ndice_imgs =  │ │
# │ │               ["①","②","'+105,                                                               │ │
# │ │               │   '# Random Dice Problem \nfrom random import randint as ri \n\ndice_imgs =  │ │
# │ │               ["①","②","'+163,                                                               │ │
# │ │               │   ... +6                                                                     │ │
# │ │               ]                                                                              │ │
# │ │     inspect = <function inspect at 0x799ae8107f40>                                           │ │
# │ │     install = <function install at 0x799ae760b520>                                           │ │
# │ │    Markdown = <class 'rich.markdown.Markdown'>                                               │ │
# │ │      myfunc = <function myfunc at 0x799ae7435090>                                            │ │
# │ │        open = <function open at 0x799b1a3a08b0>                                              │ │
# │ │         Out = {                                                                              │ │
# │ │               │   1: <bound method InteractiveShell.excepthook of                            │ │
# │ │               <ipykernel.zmqshell.ZMQInteractiveShell object at 0x799b191d6680>>             │ │
# │ │               }                                                                              │ │
# │ │       Panel = <class 'rich.panel.Panel'>                                                     │ │
# │ │      pprint = <function pprint at 0x799ae76c85e0>                                            │ │
# │ │      Prompt = <class 'rich.prompt.Prompt'>                                                   │ │
# │ │        quit = <IPython.core.autocall.ZMQExitAutocall object at 0x799b191d7400>               │ │
# │ │          ri = <bound method Random.randint of <random.Random object at 0x5cf97e2c9690>>      │ │
# │ │      rprint = <function print at 0x799ae8107e20>                                             │ │
# │ │       Style = <class 'rich.style.Style'>                                                     │ │
# │ │        Text = <class 'rich.text.Text'>                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# IndexError: list index out of range

# %%
# Testing the random int function 
from random import randint as ri 
for i in range(1,10):
    rprint(f'Turn {i} = {ri(0,5)}')
# Out:
# Turn 1 = 2
# Turn 2 = 4
# Turn 3 = 4
# Turn 4 = 4
# Turn 5 = 1
# Turn 6 = 0
# Turn 7 = 3
# Turn 8 = 5
# Turn 9 = 0
