# %% [markdown]
# <div style="background: url(https://media0.giphy.com/media/3ohhwJlKHGchQUtvBS/200w.webp?cid=ecf05e472cz0mxtxpwweb3817ym44zo0o4i3hjdlbmnzfnqy&ep=v1_gifs_related&rid=200w.webp) repeat; color: #00ff00; padding: 2px; text-align: center;background-size: cover; text-shadow: 00 0 20px #ec4899">
#     <h1>Day 14 - Panty</h1>
#
# </div>
#
# 1. [`Colors`](https://rich.readthedocs.io/en/latest/appendix/colors.html?highlight=colors) _ list of standard colors that can be printed out
# 2. [`Ascii Banne Generator`](https://manytools.org/hacker-tools/ascii-banner/) - Used this to generate nice banners below
# 3. [`AsciiFlow`](https://asciiflow.com/#/) - Draw ASCII digrams you can then use this

# %%
# Prettifyer code

# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
from rich.style import Style # For styles colors
from rich.text import Text # For text Styles
console = Console() # Standard code to access console
from rich.traceback import install
install(show_locals=True)
# -------------------------------------------------------
# Out:
# <bound method InteractiveShell.excepthook of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7c9d812de620>>

# %% [markdown]
# # Testing out random printing of lists

# %%
data = [
    {
        'name': 'Instagram',
        'follower_count': 346,
        'description': 'Social media platform',
        'country': 'United States'
    },
    {
        'name': 'Cristiano Ronaldo',
        'follower_count': 215,
        'description': 'Footballer',
        'country': 'Portugal'
    },
    {
        'name': 'Ariana Grande',
        'follower_count': 183,
        'description': 'Musician and actress',
        'country': 'United States'
    },
    {
        'name': 'Dwayne Johnson',
        'follower_count': 181,
        'description': 'Actor and professional wrestler',
        'country': 'United States'
    },
]
    

inspect(data)
# Out:
# ╭─────────────────────── <class 'list'> ────────────────────────╮
# │ Built-in mutable sequence.                                    │
# │                                                               │
# │ ╭───────────────────────────────────────────────────────────╮ │
# │ │ [                                                         │ │
# │ │ │   {                                                     │ │
# │ │ │   │   'name': 'Instagram',                              │ │
# │ │ │   │   'follower_count': 346,                            │ │
# │ │ │   │   'description': 'Social media platform',           │ │
# │ │ │   │   'country': 'United States'                        │ │
# │ │ │   },                                                    │ │
# │ │ │   {                                                     │ │
# │ │ │   │   'name': 'Cristiano Ronaldo',                      │ │
# │ │ │   │   'follower_count': 215,                            │ │
# │ │ │   │   'description': 'Footballer',                      │ │
# │ │ │   │   'country': 'Portugal'                             │ │
# │ │ │   },                                                    │ │
# │ │ │   {                                                     │ │
# │ │ │   │   'name': 'Ariana Grande',                          │ │
# │ │ │   │   'follower_count': 183,                            │ │
# │ │ │   │   'description': 'Musician and actress',            │ │
# │ │ │   │   'country': 'United States'                        │ │
# │ │ │   },                                                    │ │
# │ │ │   {                                                     │ │
# │ │ │   │   'name': 'Dwayne Johnson',                         │ │
# │ │ │   │   'follower_count': 181,                            │ │
# │ │ │   │   'description': 'Actor and professional wrestler', │ │
# │ │ │   │   'country': 'United States'                        │ │
# │ │ │   }                                                     │ │
# │ │ ]                                                         │ │
# │ ╰───────────────────────────────────────────────────────────╯ │
# │                                                               │
# │ 36 attribute(s) not shown. Run inspect(inspect) for options.  │
# ╰───────────────────────────────────────────────────────────────╯

# %%
# Testing out printing the data 

# print on element of the array 
rprint(data[0])
pprint(data[0], expand_all=True)
# Out:
# {'name': 'Instagram', 'follower_count': 346, 'description': 'Social media platform', 'country': 'United States'}
# {
# │   'name': 'Instagram',
# │   'follower_count': 346,
# │   'description': 'Social media platform',
# │   'country': 'United States'
# }

# %%
# Print out 1st arrayobject , second element
pprint(data[0]['name'], expand_all=True)
# Out:
# 'Instagram'

# %%
# write a dictionary for the object 

myobj1 = {
    'name': 'Instagram',
   'follower_count': 346,
   'description': 'Social media platform',
   'country': 'United States'
}

rprint(myobj1['name'])

myArr = ['name', 'followr_count', 'description', 'country' ]

# use elements of array to get object element 

rprint(myArr[0])
# Out:
# Instagram
# name

# %%
myArr = ['name', 'followr_count', 'description', 'country' ]

# use elements of array to get object element 

rprint(myArr[0])
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:5                                                                                    │
# │                                                                                                  │
# │   2                                                                                              │
# │   3 # use elements of array to get object element                                                │
# │   4                                                                                              │
# │ ❱ 5 rprint(myArr[0])                                                                             │
# │   6                                                                                              │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │         box = <module 'rich.box' from '/opt/conda/lib/python3.10/site-packages/rich/box.py'> │ │
# │ │     Console = <class 'rich.console.Console'>                                                 │ │
# │ │     console = <console width=115 ColorSystem.TRUECOLOR>                                      │ │
# │ │        data = [                                                                              │ │
# │ │               │   {                                                                          │ │
# │ │               │   │   'name': 'Instagram',                                                   │ │
# │ │               │   │   'follower_count': 346,                                                 │ │
# │ │               │   │   'description': 'Social media platform',                                │ │
# │ │               │   │   'country': 'United States'                                             │ │
# │ │               │   },                                                                         │ │
# │ │               │   {                                                                          │ │
# │ │               │   │   'name': 'Cristiano Ronaldo',                                           │ │
# │ │               │   │   'follower_count': 215,                                                 │ │
# │ │               │   │   'description': 'Footballer',                                           │ │
# │ │               │   │   'country': 'Portugal'                                                  │ │
# │ │               │   },                                                                         │ │
# │ │               │   {                                                                          │ │
# │ │               │   │   'name': 'Ariana Grande',                                               │ │
# │ │               │   │   'follower_count': 183,                                                 │ │
# │ │               │   │   'description': 'Musician and actress',                                 │ │
# │ │               │   │   'country': 'United States'                                             │ │
# │ │               │   },                                                                         │ │
# │ │               │   {                                                                          │ │
# │ │               │   │   'name': 'Dwayne Johnson',                                              │ │
# │ │               │   │   'follower_count': 181,                                                 │ │
# │ │               │   │   'description': 'Actor and professional wrestler',                      │ │
# │ │               │   │   'country': 'United States'                                             │ │
# │ │               │   }                                                                          │ │
# │ │               ]                                                                              │ │
# │ │        exit = <IPython.core.autocall.ZMQExitAutocall object at 0x7c9d812df3a0>               │ │
# │ │ get_ipython = <bound method InteractiveShell.get_ipython of                                  │ │
# │ │               <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7c9d812de620>>             │ │
# │ │          In = [                                                                              │ │
# │ │               │   '',                                                                        │ │
# │ │               │   "data = [\n    {\n        'name': 'Instagram',\n        'follower_count':  │ │
# │ │               346,\n     "+584,                                                              │ │
# │ │               │   '# Prettifyer code\n\n#                                                    │ │
# │ │               ------------------------------------------------------\nfrom'+636,             │ │
# │ │               │   "data = [\n    {\n        'name': 'Instagram',\n        'follower_count':  │ │
# │ │               346,\n     "+584,                                                              │ │
# │ │               │   '# Testing out printing the data \n\n# print on element of the array       │ │
# │ │               \nrprint(data[0'+2,                                                            │ │
# │ │               │   '# Testing out printing the data \n\n# print on element of the array       │ │
# │ │               \nrprint(data[0'+35,                                                           │ │
# │ │               │   '# Print out 1st arrayobject , second element\npprint(data[0][1],          │ │
# │ │               expand_all=True)',                                                             │ │
# │ │               │   "# Print out 1st arrayobject , second element\npprint(data[0]['name'],     │ │
# │ │               expand_all="+5,                                                                │ │
# │ │               │   "# write a dictionary for the object \n\nmyobj1 = {\n    'name':           │ │
# │ │               'Instagram',\n   'fo"+94,                                                      │ │
# │ │               │   "# write a dictionary for the object \n\nmyobj1 = {\n    'name':           │ │
# │ │               'Instagram',\n   'fo"+118,                                                     │ │
# │ │               │   ... +9                                                                     │ │
# │ │               ]                                                                              │ │
# │ │     inspect = <function inspect at 0x7c9d4f735c60>                                           │ │
# │ │     install = <function install at 0x7c9d4f3148b0>                                           │ │
# │ │    Markdown = <class 'rich.markdown.Markdown'>                                               │ │
# │ │       myArr = ['name', 'followr_count', 'description', 'country']                            │ │
# │ │      myobj1 = {                                                                              │ │
# │ │               │   'name': 'Instagram',                                                       │ │
# │ │               │   'follower_count': 346,                                                     │ │
# │ │               │   'description': 'Social media platform',                                    │ │
# │ │               │   'country': 'United States'                                                 │ │
# │ │               }                                                                              │ │
# │ │        open = <function open at 0x7c9d824b48b0>                                              │ │
# │ │         Out = {                                                                              │ │
# │ │               │   2: <bound method InteractiveShell.excepthook of                            │ │
# │ │               <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7c9d812de620>>             │ │
# │ │               }                                                                              │ │
# │ │       Panel = <class 'rich.panel.Panel'>                                                     │ │
# │ │      pprint = <function pprint at 0x7c9d4f3ea200>                                            │ │
# │ │      Prompt = <class 'rich.prompt.Prompt'>                                                   │ │
# │ │        quit = <IPython.core.autocall.ZMQExitAutocall object at 0x7c9d812df3a0>               │ │
# │ │      rprint = 'Instagram'                                                                    │ │
# │ │       Style = <class 'rich.style.Style'>                                                     │ │
# │ │        Text = <class 'rich.text.Text'>                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: 'str' object is not callable
