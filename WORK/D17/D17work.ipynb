# %% [markdown]
# <div style="background: url(https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExbHN3enVoaG02bHY0bGN5czQ5N2h2MWZwMm1lcTB5NG5iZHIyNThqOSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/xUPGGu9zmB3gYjxzdC/giphy.webp) repeat; color: #00ff00; padding: 2px; text-align: center;background-size: cover; text-shadow: 00 0 20px #ec4899">
#     <h1>Day17 - Intermediate - TheQuizProject and Benefits of OOP</h1>
#
# </div>
#
# 1. [`Colors`](https://rich.readthedocs.io/en/latest/appendix/colors.html?highlight=colors) _ list of standard colors that can be printed out
# 2. [`Ascii Banne Generator`](https://manytools.org/hacker-tools/ascii-banner/) - Used this to generate nice banners below
# 3. [`AsciiFlow`](https://asciiflow.com/#/) - Draw ASCII digrams you can then use this

# %% [markdown]
# <div style="background-color: #000502; color: #16a34a; padding: 10px; border-radius: 5px; font-size: 25px; text-align:center">
#   <a class="anchor" id="toc" style="text-decoration: none;">Table of Contents</a>
# </div>
#
# - ### [Lesson Summary](#s0)
# - ### [156 - Create own Class](#s1)
# - ### [158 - Methods158 - Methods](#s2)
# - ### [Quiz Game Work](#s3)

# %%
# Prettify 
# Prettifyer code

# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
from rich.style import Style # For styles colors
from rich.text import Text # For text Styles
console = Console() # Standard code to access console
from rich.traceback import install
install(show_locals=True)
# -------------------------------------------------------
# Out:
# <bound method InteractiveShell.excepthook of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7c2b220ba620>>

# %% [markdown]
# # Lesson Summary <a class="anchor" id="s0"></a> [↩️TOC](#toc)
#
# 1. Focus is on OOP.
# 2. Learning is about making projects

# %% [markdown]
# # 156 - Create own Class <a class="anchor" id="s1"></a> [↩️TOC](#toc)

# %%
# Creating a class 

class User:
    pass
    
    
# Instantiation of the class 
user_1 = User()

# Adding an attribute 
user_1.id = "001"
user_1.name = "Bina"

rprint(f'''
id   = {user_1.id}
name = {user_1.name}
''')
# Out:
# id   = 001
# name = Bina

# %%
# Using constructor 

class User2:
    def __init__(self):
        rprint('Suck')
        
# Instantiating the class 
user_2 = User2()
user_2.id = "99"
user_2.id = "Nina"

rprint(user_2)
rprint(user_2.id)
# Out:
# Suck
# <__main__.User2 object at 0x7c2ae9ab6f50>
# Nina

# %%
# adding parameters 
class User3:
    # Constructor
    def __init__(self, user_id, username, follower):
        rprint(f'User3 Class')
        self.id = user_id
        self.username = username # The name should be same as parameter
        self.follower = 0
        

# Instantiate 
user_3 = User3("001", "Fony", 90)

rprint(f'{user_3.id}, {user_3.username}')

# Default can be printed like this
rprint(user_3.follower)
# Out:
# User3 Class
# 001, Fony
# 0

# %% [markdown]
# # 158 - Methods <a class="anchor" id="s2"></a> [↩️TOC](#toc)

# %%
# Methods

class User4:
    
    def __init__(self, user_id, username):
        self.id = user_id
        self.username = username
        self.follower = 0
        self.following = 0
        
    def follow(self, user):
        user.following +=1
        self.following +=1
        
user_1 = User4("001", "Nina")
user_2 = User4("002", "fina")

rprint(f'''
Printing user_1 and user_2 
{user_1.id} {user_1.username} {user_1.follower} {user_1.following} 
{user_2.id} {user_2.username} {user_2.follower} {user_2.following}
''')

user_1.follow(user_2)
rprint(f'''
Printing after follow function
---
User 1 = {user_1.follower} {user_1.following}
User 2 = {user_2.follower} {user_2.following}
''')
# Out:
# Printing user_1 and user_2
# 001 Nina 0 0
# 002 fina 0 0
# Printing after follow function
# ---
# User 1 = 0 1
# User 2 = 0 1

# %% [markdown]
# # Quiz Game Work  <a class="anchor" id="s3"></a> [↩️TOC](#toc)

# %% [markdown]
# 1. All lessons work will directly go in here, not seprating into sections
# 2. [MainReplitForQuizWork](https://replit.com/@appbrewery/quiz-game-start)

# %%
# Quiz Data
question_data = [
    {"text": "A slug's blood is green.", "answer": "True"},
    {"text": "The loudest animal is the African Elephant.", "answer": "False"},
    {"text": "Approximately one quarter of human bones are in the feet.", "answer": "True"},
    {"text": "The total surface area of a human lungs is the size of a football pitch.", "answer": "True"},
    {"text": "In West Virginia, USA, if you accidentally hit an animal with your car, you are free to take it home to eat.", "answer": "True"},
    {"text": "In London, UK, if you happen to die in the House of Parliament, you are entitled to a state funeral.", "answer": "False"},
    {"text": "It is illegal to pee in the Ocean in Portugal.", "answer": "True"},
    {"text": "You can lead a cow down stairs but not up stairs.", "answer": "False"},
    {"text": "Google was originally called 'Backrub'.", "answer": "True"},
    {"text": "Buzz Aldrin's mother's maiden name was 'Moon'.", "answer": "True"},
    {"text": "No piece of square dry paper can be folded in half more than 7 times.", "answer": "False"},
    {"text": "A few ounces of chocolate can to kill a small dog.", "answer": "True"}
]

# %%
# Accessing the data like this , its a dictrionary
pprint(f'{question_data[1]["text"]} , {question_data[1]["answer"]}')
# Out:
# 'The loudest animal is the African Elephant. , False'

# %%
# Create class 

class Question:
    def __init__(self, q_text, q_answer):
        self.text = q_text 
        self.answer = q_answer

question_bank = []
for question in question_data:
    question_text = question["text"]
    question_answer = question["answer"]
    new_question = Question(question_text, question_answer)
    question_bank.append(new_question)


# Printing the objects
rprint(question_bank)
pprint(question_bank)
inspect(question_bank)
# Out:
# [
#     <__main__.Question object at 0x7c2aeb7ef040>,
#     <__main__.Question object at 0x7c2aeb7ec700>,
#     <__main__.Question object at 0x7c2aeb9b5b40>,
#     <__main__.Question object at 0x7c2aeb9b7670>,
#     <__main__.Question object at 0x7c2aeb9b6fb0>,
#     <__main__.Question object at 0x7c2aeb9b5300>,
#     <__main__.Question object at 0x7c2aeb821e40>,
#     <__main__.Question object at 0x7c2ae9133f10>,
#     <__main__.Question object at 0x7c2ae91333d0>,
#     <__main__.Question object at 0x7c2ae9133dc0>,
#     <__main__.Question object at 0x7c2ae9133910>,
#     <__main__.Question object at 0x7c2ae91332b0>
# ]
# [
# │   <__main__.Question object at 0x7c2aeb7ef040>,
# │   <__main__.Question object at 0x7c2aeb7ec700>,
# │   <__main__.Question object at 0x7c2aeb9b5b40>,
# │   <__main__.Question object at 0x7c2aeb9b7670>,
# │   <__main__.Question object at 0x7c2aeb9b6fb0>,
# │   <__main__.Question object at 0x7c2aeb9b5300>,
# │   <__main__.Question object at 0x7c2aeb821e40>,
# │   <__main__.Question object at 0x7c2ae9133f10>,
# │   <__main__.Question object at 0x7c2ae91333d0>,
# │   <__main__.Question object at 0x7c2ae9133dc0>,
# │   <__main__.Question object at 0x7c2ae9133910>,
# │   <__main__.Question object at 0x7c2ae91332b0>
# ]
# ╭─────────────────────── <class 'list'> ───────────────────────╮
# │ Built-in mutable sequence.                                   │
# │                                                              │
# │ ╭──────────────────────────────────────────────────────────╮ │
# │ │ [                                                        │ │
# │ │ │   <__main__.Question object at 0x7c2aeb7ef040>,        │ │
# │ │ │   <__main__.Question object at 0x7c2aeb7ec700>,        │ │
# │ │ │   <__main__.Question object at 0x7c2aeb9b5b40>,        │ │
# │ │ │   <__main__.Question object at 0x7c2aeb9b7670>,        │ │
# │ │ │   <__main__.Question object at 0x7c2aeb9b6fb0>,        │ │
# │ │ │   <__main__.Question object at 0x7c2aeb9b5300>,        │ │
# │ │ │   <__main__.Question object at 0x7c2aeb821e40>,        │ │
# │ │ │   <__main__.Question object at 0x7c2ae9133f10>,        │ │
# │ │ │   <__main__.Question object at 0x7c2ae91333d0>,        │ │
# │ │ │   <__main__.Question object at 0x7c2ae9133dc0>,        │ │
# │ │ │   ... +2                                               │ │
# │ │ ]                                                        │ │
# │ ╰──────────────────────────────────────────────────────────╯ │
# │                                                              │
# │ 36 attribute(s) not shown. Run inspect(inspect) for options. │
# ╰──────────────────────────────────────────────────────────────╯

# %%
# Accessing data in question_bank 
rprint(question_bank[0].text)
rprint(question_bank[0].answer)
# Out:
# A slug's blood is green.
# True

# %%
# Writingt he main logic for the quiz program 

class QuizBrain:
    
    def __init__(self, q_list):
        self.question_number = 0 
        self.question_list = q_list
        
    def next_question(self):
        current_question = self.question_list[self.question_number]
        Prompt.ask(f'''[#00ff00]Q-{self.question_number} : [#00ffff]{current_question.text} (True/False)''', choices = ["True", "False"])

# crate new quiz 
quiz = QuizBrain(question_bank)
quiz.next_question()
# Out:
# Q-0 : A slug's blood is green. (True/False) [True/False]:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:15                                                                                   │
# │                                                                                                  │
# │   12                                                                                             │
# │   13 # crate new quiz                                                                            │
# │   14 quiz = QuizBrain(question_bank)                                                             │
# │ ❱ 15 quiz.next_question()                                                                        │
# │   16                                                                                             │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │             box = <module 'rich.box' from                                                    │ │
# │ │                   '/opt/conda/lib/python3.10/site-packages/rich/box.py'>                     │ │
# │ │         Console = <class 'rich.console.Console'>                                             │ │
# │ │         console = <console width=115 ColorSystem.TRUECOLOR>                                  │ │
# │ │            exit = <IPython.core.autocall.ZMQExitAutocall object at 0x7c2b220bb3a0>           │ │
# │ │     get_ipython = <bound method InteractiveShell.get_ipython of                              │ │
# │ │                   <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7c2b220ba620>>         │ │
# │ │              In = [                                                                          │ │
# │ │                   │   '',                                                                    │ │
# │ │                   │   '# Quiz Data\nquestion_data = [\n{"text": "A slug\'s blood is green.", │ │
# │ │                   "answer": "Tr'+1041,                                                       │ │
# │ │                   │   "get_ipython().run_line_magic('pprint', '(question_data[0])')",        │ │
# │ │                   │   '# Prettify \n# Prettifyer code\n\n#                                   │ │
# │ │                   -----------------------------------------------'+648,                      │ │
# │ │                   │   'pprint(question_data[0])',                                            │ │
# │ │                   │   'pprint(question_data[0]["answer"])',                                  │ │
# │ │                   │   '# Accessing the data like this , its a                                │ │
# │ │                   dictrionary\npprint(question_data[0]["text'+3,                             │ │
# │ │                   │   '# Accessing the data like this , its a                                │ │
# │ │                   dictrionary\npprint(question_data[1]["text'+3,                             │ │
# │ │                   │   '# Accessing the data like this , its a                                │ │
# │ │                   dictrionary\npprint(question_data[1]["text'+32,                            │ │
# │ │                   │   '# Accessing the data like this , its a                                │ │
# │ │                   dictrionary\npprint(f\'{question_data[1]["t'+39,                           │ │
# │ │                   │   ... +46                                                                │ │
# │ │                   ]                                                                          │ │
# │ │         inspect = <function inspect at 0x7c2aeb93d240>                                       │ │
# │ │         install = <function install at 0x7c2aebdb0430>                                       │ │
# │ │        Markdown = <class 'rich.markdown.Markdown'>                                           │ │
# │ │           new_q = <__main__.Question object at 0x7c2aeba8f5b0>                               │ │
# │ │    new_question = <__main__.Question object at 0x7c2ae91332b0>                               │ │
# │ │            open = <function open at 0x7c2b232508b0>                                          │ │
# │ │             Out = {                                                                          │ │
# │ │                   │   3: <bound method InteractiveShell.excepthook of                        │ │
# │ │                   <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7c2b220ba620>>,        │ │
# │ │                   │   30: <bound method InteractiveShell.excepthook of                       │ │
# │ │                   <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7c2b220ba620>>         │ │
# │ │                   }                                                                          │ │
# │ │           Panel = <class 'rich.panel.Panel'>                                                 │ │
# │ │          pprint = <function pprint at 0x7c2aebf59750>                                        │ │
# │ │          Prompt = <class 'rich.prompt.Prompt'>                                               │ │
# │ │        Question = <class '__main__.Question'>                                                │ │
# │ │        question = {                                                                          │ │
# │ │                   │   'text': 'A few ounces of chocolate can to kill a small dog.',          │ │
# │ │                   │   'answer': 'True'                                                       │ │
# │ │                   }                                                                          │ │
# │ │ question_answer = 'True'                                                                     │ │
# │ │   question_bank = [                                                                          │ │
# │ │                   │   <__main__.Question object at 0x7c2aeb7ef040>,                          │ │
# │ │                   │   <__main__.Question object at 0x7c2aeb7ec700>,                          │ │
# │ │                   │   <__main__.Question object at 0x7c2aeb9b5b40>,                          │ │
# │ │                   │   <__main__.Question object at 0x7c2aeb9b7670>,                          │ │
# │ │                   │   <__main__.Question object at 0x7c2aeb9b6fb0>,                          │ │
# │ │                   │   <__main__.Question object at 0x7c2aeb9b5300>,                          │ │
# │ │                   │   <__main__.Question object at 0x7c2aeb821e40>,                          │ │
# │ │                   │   <__main__.Question object at 0x7c2ae9133f10>,                          │ │
# │ │                   │   <__main__.Question object at 0x7c2ae91333d0>,                          │ │
# │ │                   │   <__main__.Question object at 0x7c2ae9133dc0>,                          │ │
# │ │                   │   ... +2                                                                 │ │
# │ │                   ]                                                                          │ │
# │ │   question_data = [                                                                          │ │
# │ │                   │   {'text': "A slug's blood is green.", 'answer': 'True'},                │ │
# │ │                   │   {                                                                      │ │
# │ │                   │   │   'text': 'The loudest animal is the African Elephant.',             │ │
# │ │                   │   │   'answer': 'False'                                                  │ │
# │ │                   │   },                                                                     │ │
# │ │                   │   {                                                                      │ │
# │ │                   │   │   'text': 'Approximately one quarter of human bones are in the       │ │
# │ │                   feet.',                                                                    │ │
# │ │                   │   │   'answer': 'True'                                                   │ │
# │ │                   │   },                                                                     │ │
# │ │                   │   {                                                                      │ │
# │ │                   │   │   'text': 'The total surface area of a human lungs is the size of a  │ │
# │ │                   football pitch.',                                                          │ │
# │ │                   │   │   'answer': 'True'                                                   │ │
# │ │                   │   },                                                                     │ │
# │ │                   │   {                                                                      │ │
# │ │                   │   │   'text': 'In West Virginia, USA, if you accidentally hit an animal  │ │
# │ │                   with your car, you are '+28,                                               │ │
# │ │                   │   │   'answer': 'True'                                                   │ │
# │ │                   │   },                                                                     │ │
# │ │                   │   {                                                                      │ │
# │ │                   │   │   'text': 'In London, UK, if you happen to die in the House of       │ │
# │ │                   Parliament, you are entitled'+20,                                          │ │
# │ │                   │   │   'answer': 'False'                                                  │ │
# │ │                   │   },                                                                     │ │
# │ │                   │   {                                                                      │ │
# │ │                   │   │   'text': 'It is illegal to pee in the Ocean in Portugal.',          │ │
# │ │                   │   │   'answer': 'True'                                                   │ │
# │ │                   │   },                                                                     │ │
# │ │                   │   {                                                                      │ │
# │ │                   │   │   'text': 'You can lead a cow down stairs but not up stairs.',       │ │
# │ │                   │   │   'answer': 'False'                                                  │ │
# │ │                   │   },                                                                     │ │
# │ │                   │   {                                                                      │ │
# │ │                   │   │   'text': "Google was originally called 'Backrub'.",                 │ │
# │ │                   │   │   'answer': 'True'                                                   │ │
# │ │                   │   },                                                                     │ │
# │ │                   │   {                                                                      │ │
# │ │                   │   │   'text': "Buzz Aldrin's mother's maiden name was 'Moon'.",          │ │
# │ │                   │   │   'answer': 'True'                                                   │ │
# │ │                   │   },                                                                     │ │
# │ │                   │   ... +2                                                                 │ │
# │ │                   ]                                                                          │ │
# │ │   question_text = 'A few ounces of chocolate can to kill a small dog.'                       │ │
# │ │            quit = <IPython.core.autocall.ZMQExitAutocall object at 0x7c2b220bb3a0>           │ │
# │ │            quiz = <__main__.QuizBrain object at 0x7c2ae9087040>                              │ │
# │ │       QuizBrain = <class '__main__.QuizBrain'>                                               │ │
# │ │          rprint = <function print at 0x7c2aeb93d120>                                         │ │
# │ │           Style = <class 'rich.style.Style'>                                                 │ │
# │ │            Text = <class 'rich.text.Text'>                                                   │ │
# │ │            User = <class '__main__.User'>                                                    │ │
# │ │           User2 = <class '__main__.User2'>                                                   │ │
# │ │           User3 = <class '__main__.User3'>                                                   │ │
# │ │           User4 = <class '__main__.User4'>                                                   │ │
# │ │          user_1 = <__main__.User4 object at 0x7c2aebc04790>                                  │ │
# │ │          user_2 = <__main__.User4 object at 0x7c2aebc05090>                                  │ │
# │ │          user_3 = <__main__.User3 object at 0x7c2aebabc1f0>                                  │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ in next_question:11                                                                              │
# │                                                                                                  │
# │    8 │                                                                                           │
# │    9 │   def next_question(self):                                                                │
# │   10 │   │   current_question = self.question_list[self.question_number]                         │
# │ ❱ 11 │   │   Prompt.ask(f'''[#00ff00]Q-{self.question_number} : [#00ffff]{current_question.te    │
# │   12                                                                                             │
# │   13 # crate new quiz                                                                            │
# │   14 quiz = QuizBrain(question_bank)                                                             │
# │                                                                                                  │
# │ ╭───────────────────────────── locals ─────────────────────────────╮                             │
# │ │ current_question = <__main__.Question object at 0x7c2aeb7ef040>  │                             │
# │ │             self = <__main__.QuizBrain object at 0x7c2ae9087040> │                             │
# │ ╰──────────────────────────────────────────────────────────────────╯                             │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/rich/prompt.py:141 in ask                                │
# │                                                                                                  │
# │   138 │   │   │   show_default=show_default,                                                     │
# │   139 │   │   │   show_choices=show_choices,                                                     │
# │   140 │   │   )                                                                                  │
# │ ❱ 141 │   │   return _prompt(default=default, stream=stream)                                     │
# │   142 │                                                                                          │
# │   143 │   def render_default(self, default: DefaultType) -> Text:                                │
# │   144 │   │   """Turn the supplied default in to a Text instance.                                │
# │                                                                                                  │
# │ ╭──────────────────────────────────── locals ────────────────────────────────────╮               │
# │ │      choices = ['True', 'False']                                               │               │
# │ │          cls = <class 'rich.prompt.Prompt'>                                    │               │
# │ │      console = None                                                            │               │
# │ │      default = Ellipsis                                                        │               │
# │ │     password = False                                                           │               │
# │ │       prompt = "[#00ff00]Q-0 : [#00ffff]A slug's blood is green. (True/False)" │               │
# │ │ show_choices = True                                                            │               │
# │ │ show_default = True                                                            │               │
# │ │       stream = None                                                            │               │
# │ ╰────────────────────────────────────────────────────────────────────────────────╯               │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/rich/prompt.py:274 in __call__                           │
# │                                                                                                  │
# │   271 │   │   while True:                                                                        │
# │   272 │   │   │   self.pre_prompt()                                                              │
# │   273 │   │   │   prompt = self.make_prompt(default)                                             │
# │ ❱ 274 │   │   │   value = self.get_input(self.console, prompt, self.password, stream=stream)     │
# │   275 │   │   │   if value == "" and default != ...:                                             │
# │   276 │   │   │   │   return default                                                             │
# │   277 │   │   │   try:                                                                           │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ default = Ellipsis                                                                           │ │
# │ │  prompt = <text "Q-0 : A slug's blood is green. (True/False) [True/False]: " [Span(0, 43,    │ │
# │ │           '#00ff00'), Span(6, 43, '#00ffff'), Span(44, 56, 'prompt.choices')]>               │ │
# │ │    self = <rich.prompt.Prompt object at 0x7c2ae9085270>                                      │ │
# │ │  stream = None                                                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/rich/prompt.py:203 in get_input                          │
# │                                                                                                  │
# │   200 │   │   Returns:                                                                           │
# │   201 │   │   │   str: String from user.                                                         │
# │   202 │   │   """                                                                                │
# │ ❱ 203 │   │   return console.input(prompt, password=password, stream=stream)                     │
# │   204 │                                                                                          │
# │   205 │   def check_choice(self, value: str) -> bool:                                            │
# │   206 │   │   """Check value is in the list of valid choices.                                    │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │      cls = <class 'rich.prompt.Prompt'>                                                      │ │
# │ │  console = <console width=115 ColorSystem.TRUECOLOR>                                         │ │
# │ │ password = False                                                                             │ │
# │ │   prompt = <text "Q-0 : A slug's blood is green. (True/False) [True/False]: " [Span(0, 43,   │ │
# │ │            '#00ff00'), Span(6, 43, '#00ffff'), Span(44, 56, 'prompt.choices')]>              │ │
# │ │   stream = None                                                                              │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/rich/console.py:2123 in input                            │
# │                                                                                                  │
# │   2120 │   │   │   if stream:                                                                    │
# │   2121 │   │   │   │   result = stream.readline()                                                │
# │   2122 │   │   │   else:                                                                         │
# │ ❱ 2123 │   │   │   │   result = input()                                                          │
# │   2124 │   │   return result                                                                     │
# │   2125 │                                                                                         │
# │   2126 │   def export_text(self, *, clear: bool = True, styles: bool = False) -> str:            │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │    emoji = True                                                                              │ │
# │ │   markup = True                                                                              │ │
# │ │ password = False                                                                             │ │
# │ │   prompt = <text "Q-0 : A slug's blood is green. (True/False) [True/False]: " [Span(0, 43,   │ │
# │ │            '#00ff00'), Span(6, 43, '#00ffff'), Span(44, 56, 'prompt.choices')]>              │ │
# │ │     self = <console width=115 ColorSystem.TRUECOLOR>                                         │ │
# │ │   stream = None                                                                              │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py:1262 in raw_input                │
# │                                                                                                  │
# │   1259 │   │   if not self._allow_stdin:                                                         │
# │   1260 │   │   │   msg = "raw_input was called, but this frontend does not support input reques  │
# │   1261 │   │   │   raise StdinNotImplementedError(msg)                                           │
# │ ❱ 1262 │   │   return self._input_request(                                                       │
# │   1263 │   │   │   str(prompt),                                                                  │
# │   1264 │   │   │   self._parent_ident["shell"],                                                  │
# │   1265 │   │   │   self.get_parent("shell"),                                                     │
# │                                                                                                  │
# │ ╭─────────────────────────────── locals ───────────────────────────────╮                         │
# │ │ prompt = ''                                                          │                         │
# │ │   self = <ipykernel.ipkernel.IPythonKernel object at 0x7c2b220ba110> │                         │
# │ ╰──────────────────────────────────────────────────────────────────────╯                         │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py:1305 in _input_request           │
# │                                                                                                  │
# │   1302 │   │   │   except KeyboardInterrupt:                                                     │
# │   1303 │   │   │   │   # re-raise KeyboardInterrupt, to truncate traceback                       │
# │   1304 │   │   │   │   msg = "Interrupted by user"                                               │
# │ ❱ 1305 │   │   │   │   raise KeyboardInterrupt(msg) from None                                    │
# │   1306 │   │   │   except Exception:                                                             │
# │   1307 │   │   │   │   self.log.warning("Invalid Message:", exc_info=True)                       │
# │   1308                                                                                           │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │  content = {'prompt': '', 'password': False}                                                 │ │
# │ │    ident = [b'3680fdf0-3975-47df-adad-f35925df8ff0']                                         │ │
# │ │      msg = 'Interrupted by user'                                                             │ │
# │ │   parent = {                                                                                 │ │
# │ │            │   'header': {                                                                   │ │
# │ │            │   │   'date': datetime.datetime(2024, 7, 17, 9, 34, 42, 757000,                 │ │
# │ │            tzinfo=tzlocal()),                                                                │ │
# │ │            │   │   'msg_id': '96b59f57-6192-4beb-bdb0-bbba5cf2385f',                         │ │
# │ │            │   │   'msg_type': 'execute_request',                                            │ │
# │ │            │   │   'session': '3680fdf0-3975-47df-adad-f35925df8ff0',                        │ │
# │ │            │   │   'username': '',                                                           │ │
# │ │            │   │   'version': '5.2'                                                          │ │
# │ │            │   },                                                                            │ │
# │ │            │   'msg_id': '96b59f57-6192-4beb-bdb0-bbba5cf2385f',                             │ │
# │ │            │   'msg_type': 'execute_request',                                                │ │
# │ │            │   'parent_header': {},                                                          │ │
# │ │            │   'metadata': {                                                                 │ │
# │ │            │   │   'scrolled': True,                                                         │ │
# │ │            │   │   'execution': {                                                            │ │
# │ │            │   │   │   'iopub.status.busy': '2024-07-17T09:32:37.739877Z',                   │ │
# │ │            │   │   │   'iopub.execute_input': '2024-07-17T09:32:37.741360Z',                 │ │
# │ │            │   │   │   'iopub.status.idle': '2024-07-17T09:32:44.727640Z',                   │ │
# │ │            │   │   │   'shell.execute_reply.started': '2024-07-17T09:32:37.741311Z',         │ │
# │ │            │   │   │   'shell.execute_reply': '2024-07-17T09:32:44.726210Z'                  │ │
# │ │            │   │   },                                                                        │ │
# │ │            │   │   'deletedCells': [],                                                       │ │
# │ │            │   │   'recordTiming': True,                                                     │ │
# │ │            │   │   'cellId': '5647c286-2d74-4859-aa88-be4471287cfe'                          │ │
# │ │            │   },                                                                            │ │
# │ │            │   'content': {                                                                  │ │
# │ │            │   │   'silent': False,                                                          │ │
# │ │            │   │   'store_history': True,                                                    │ │
# │ │            │   │   'user_expressions': {},                                                   │ │
# │ │            │   │   'allow_stdin': True,                                                      │ │
# │ │            │   │   'stop_on_error': True,                                                    │ │
# │ │            │   │   'code': '# Writingt he main logic for the quiz program \n\nclass          │ │
# │ │            QuizBrain:\n    \n    def __'+408                                                 │ │
# │ │            │   },                                                                            │ │
# │ │            │   'buffers': []                                                                 │ │
# │ │            }                                                                                 │ │
# │ │ password = False                                                                             │ │
# │ │   prompt = ''                                                                                │ │
# │ │    rlist = []                                                                                │ │
# │ │     self = <ipykernel.ipkernel.IPythonKernel object at 0x7c2b220ba110>                       │ │
# │ │    xlist = []                                                                                │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt: Interrupted by user
