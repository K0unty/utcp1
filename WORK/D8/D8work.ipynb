# %% [markdown]
# <div style="background: url(https://media2.giphy.com/media/v1.Y2lkPTc5MGI3NjExeTVzbTd2enAxdXo2ZWFmbHBnbnpqamx6cnhiMHpwc3RnYm0wenB6ciZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/KX5nwoDX97AtPvKBF6/giphy.webp) repeat; color: #00ff00; padding: 2px; text-align: center;background-size: cover; text-shadow: 00 0 20px #ec4899">
#     <h1>Day 8 - Function Paramters and Ceasar Cipher</h1>
#
# </div>
#
# 1. [`Colors`](https://rich.readthedocs.io/en/latest/appendix/colors.html?highlight=colors) _ list of standard colors that can be printed out
# 2. [`Ascii Banne Generator`](https://manytools.org/hacker-tools/ascii-banner/https://manytools.org/hacker-tools/ascii-banner/) - Used this to generate nice banners below
# 3. [`AsciiFlow`](https://asciiflow.com/#/https://asciiflow.com/#/) - Draw ASCII digrams you can then use this

# %% [markdown]
# <div style="background-color: #000502; color: #16a34a; padding: 10px; border-radius: 5px; font-size: 25px; text-align:center">
#   <a class="anchor" id="toc" style="text-decoration: none;">Table of Contents</a>
# </div>
#
#
# - ### [83 - Function With Inputs](#s83)
# - ### [85 - IC  - Paint Area Calculator](#s85)

# %%
# Prettifyer code

# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
from rich.style import Style # For styles colors
from rich.text import Text # For text Styles
console = Console() # Standard code to access console
# -------------------------------------------------------

# %% [markdown]
# ## 83 - Function With Inputs <a class="anchor" id="s83"></a> [↩️TOC](#toc)

# %%
# Writing a banner function 
def my_ban():
    """
    Prints banner panty
    """
    rprint(f'''[#d7ff00]
:'######::'########::::'###:::::'######:::::'###::::'########::
'##... ##: ##.....::::'## ##:::'##... ##:::'## ##::: ##.... ##:
 ##:::..:: ##::::::::'##:. ##:: ##:::..:::'##:. ##:: ##:::: ##:
 ##::::::: ######:::'##:::. ##:. ######::'##:::. ##: ########::
 ##::::::: ##...:::: #########::..... ##: #########: ##.. ##:::
 ##::: ##: ##::::::: ##.... ##:'##::: ##: ##.... ##: ##::. ##::
. ######:: ########: ##:::: ##:. ######:: ##:::: ##: ##:::. ##:
:......:::........::..:::::..:::......:::..:::::..::..:::::..::
:'######::'##:::'##:'########::'##::::'##:'########:'########::
'##... ##:. ##:'##:: ##.... ##: ##:::: ##: ##.....:: ##.... ##:
 ##:::..:::. ####::: ##:::: ##: ##:::: ##: ##::::::: ##:::: ##:
 ##:::::::::. ##:::: ########:: #########: ######::: ########::
 ##:::::::::: ##:::: ##.....::: ##.... ##: ##...:::: ##.. ##:::
 ##::: ##:::: ##:::: ##:::::::: ##:::: ##: ##::::::: ##::. ##::
. ######::::: ##:::: ##:::::::: ##:::: ##: ########: ##:::. ##:
:......::::::..:::::..:::::::::..:::::..::........::..:::::..::
    ''')

# %%
# call banner
my_ban()
# Out:
# :'######::'########::::'###:::::'######:::::'###::::'########::
# '##... ##: ##.....::::'## ##:::'##... ##:::'## ##::: ##.... ##:
#  ##:::..:: ##::::::::'##:. ##:: ##:::..:::'##:. ##:: ##:::: ##:
#  ##::::::: ######:::'##:::. ##:. ######::'##:::. ##: ########::
#  ##::::::: ##...:::: #########::..... ##: #########: ##.. ##:::
#  ##::: ##: ##::::::: ##.... ##:'##::: ##: ##.... ##: ##::. ##::
# . ######:: ########: ##:::: ##:. ######:: ##:::: ##: ##:::. ##:
# :......:::........::..:::::..:::......:::..:::::..::..:::::..::
# :'######::'##:::'##:'########::'##::::'##:'########:'########::
# '##... ##:. ##:'##:: ##.... ##: ##:::: ##: ##.....:: ##.... ##:
#  ##:::..:::. ####::: ##:::: ##: ##:::: ##: ##::::::: ##:::: ##:
#  ##:::::::::. ##:::: ########:: #########: ######::: ########::
#  ##:::::::::: ##:::: ##.....::: ##.... ##: ##...:::: ##.. ##:::
#  ##::: ##:::: ##:::: ##:::::::: ##:::: ##: ##::::::: ##::. ##::
# . ######::::: ##:::: ##:::::::: ##:::: ##: ########: ##:::. ##:
# :......::::::..:::::..:::::::::..:::::..::........::..:::::..::

# %% [markdown]
# Adding inputs

# %%
# Function with params 
def fet_1(fet):
    rprint(f'''
Mistress Sez
---
Lick me {fet}
Smell my {fet}
    ''')

# --- Run Func

fet_1('panty')
# Out:
# Mistress Sez
# ---
# Lick me panty
# Smell my panty

# %% [markdown]
# Positional Paramters - Parmeters will take be positional when you use function it will be called in the order

# %%
# multiple Params
def sniff(p1, p2):
    rprint(f'''
    1. Oh so want {p1}, {p2}
    ''')
sniff("ass", "armpit")

sniff('Armpit', 'panty')
# Out:
#     1. Oh so want ass, armpit
#     1. Oh so want Armpit, panty

# %%
# postiional arguments 

def snif2(f1=1, f2=2):
    rprint(f'''
    1st arg = {f1}
    2nd arg = {f2}
    ''')
    
# Keyword Arguments
snif2(f1="jam", f2="ham")
# Out:
#     1st arg = jam
#     2nd arg = ham

# %% [markdown]
# ## 85 - IC  - Paint Area Calculator <a class="anchor" id="s85"></a> [↩️TOC](#toc)

# %%
# Paint Area Calculator 
rprint(f'''
Panty Area Calculator 
''')


def pa_ca(ht,wt):
    ca = math.ceil((ht*wt)/5)
    rprint(f'''
    
    Paint Cans Required
    ---
    
    Ht = {ht}
    Wt = {wt}
    
    cans of paint = {ca}
    ''')


ht = int(Prompt.ask('What Height: '))
wt = int(Prompt.ask('What Width: '))

pa_ca(ht, wt)
# Out:
# Panty Area Calculator
# What Height: :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 21
#       8     ca = math.ceil((ht*wt)/5)
#       9     rprint(f'''
#      10
#      11     Paint Cans Required
#    (...)
#      17     cans of paint = {ca}
#      18     ''')
# ---> 21 ht = int(Prompt.ask('What Height: '))
#      22 wt = int(Prompt.ask('What Width: '))
#      24 pa_ca(ht, wt)
#
# File /opt/conda/lib/python3.10/site-packages/rich/prompt.py:141, in PromptBase.ask(cls, prompt, console, password, choices, show_default, show_choices, default, stream)
#     119 """Shortcut to construct and run a prompt loop and return the result.
#     120
#     121 Example:
#    (...)
#     131     stream (TextIO, optional): Optional text file open for reading to get input. Defaults to None.
#     132 """
#     133 _prompt = cls(
#     134     prompt,
#     135     console=console,
#    (...)
#     139     show_choices=show_choices,
#     140 )
# --> 141 return _prompt(default=default, stream=stream)
#
# File /opt/conda/lib/python3.10/site-packages/rich/prompt.py:274, in PromptBase.__call__(self, default, stream)
#     272 self.pre_prompt()
#     273 prompt = self.make_prompt(default)
# --> 274 value = self.get_input(self.console, prompt, self.password, stream=stream)
#     275 if value == "" and default != ...:
#     276     return default
#
# File /opt/conda/lib/python3.10/site-packages/rich/prompt.py:203, in PromptBase.get_input(cls, console, prompt, password, stream)
#     185 @classmethod
#     186 def get_input(
#     187     cls,
#    (...)
#     191     stream: Optional[TextIO] = None,
#     192 ) -> str:
#     193     """Get input from user.
#     194
#     195     Args:
#    (...)
#     201         str: String from user.
#     202     """
# --> 203     return console.input(prompt, password=password, stream=stream)
#
# File /opt/conda/lib/python3.10/site-packages/rich/console.py:2123, in Console.input(self, prompt, markup, emoji, password, stream)
#    2121         result = stream.readline()
#    2122     else:
# -> 2123         result = input()
#    2124 return result
#
# File /opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File /opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# -> 1305     raise KeyboardInterrupt(msg) from None
#    1306 except Exception:
#    1307     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
#  12

# %%
# rewriting the function without asking actual inputs 
import math as ma

# Using the math ceiling number

def pai2(ht, wt, co):
    ca = ma.ceil((ht*wt)/co)
    rprint(f'Answer is {ca}')
    
pai2(2,2,2)

pai2(20,211,222)
# Out:
# Answer is 2
# Answer is 20
