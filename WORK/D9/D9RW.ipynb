# %% [markdown]
# <div style="background: url(https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExc3Y3OWw1ejI5dGZ6a285N3NxYnJnZTBldGRsZmp5bHh4aDB4eWttNCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/QvMybzkScTcqHJiZx0/giphy.webp) repeat; color: #00ff00; padding: 2px; text-align: center;background-size: cover; text-shadow: 00 0 20px #ec4899">
#     <h1>Day 9 - RoughWork</h1>
#
# </div>

# %%
# Prettifyer code

# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
from rich.style import Style # For styles colors
from rich.text import Text # For text Styles
console = Console() # Standard code to access console
# -------------------------------------------------------

# %% [markdown]
# # Testing out Dictionary and adding to it

# %%
s_s = {
    "ina" : 91,
    "ana" : 90,
    "yin" : 80,
    "fon" : 99,
}

# Adding one element 
s_s['pon'] =100

# Testing pretty printing of dict
pprint(s_s, expand_all=True)
console.print(s_s)
# Out:
# {
# │   'ina': 91,
# │   'ana': 90,
# │   'yin': 80,
# │   'fon': 99,
# │   'pon': 100
# }
# {'ina': 91, 'ana': 90, 'yin': 80, 'fon': 99, 'pon': 100}

# %%
from rich.console import Console
console = Console()

try:
    do_something()
except Exception:
    console.print_exception(show_locals=True)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:5                                                                                    │
# │                                                                                                  │
# │   2 console = Console()                                                                          │
# │   3                                                                                              │
# │   4 try:                                                                                         │
# │ ❱ 5 │   do_something()                                                                           │
# │   6 except Exception:                                                                            │
# │   7 │   console.print_exception(show_locals=True)                                                │
# │   8                                                                                              │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │           _ = ''                                                                             │ │
# │ │         _dh = [PosixPath('/kaggle/working')]                                                 │ │
# │ │          _i = 's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :       │ │
# │ │               99,\n}\n\n# Add'+115                                                           │ │
# │ │         _i1 = '# Prettifyer code\n\n#                                                        │ │
# │ │               ------------------------------------------------------\nfrom'+575              │ │
# │ │         _i2 = 's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :       │ │
# │ │               99,\n}'                                                                        │ │
# │ │         _i3 = 's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :       │ │
# │ │               99,\n}\n\n# Add'+32                                                            │ │
# │ │         _i4 = 's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :       │ │
# │ │               99,\n}\n\n# Add'+45                                                            │ │
# │ │         _i5 = 's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :       │ │
# │ │               99,\n}\n\n# Add'+64                                                            │ │
# │ │         _i6 = '# Prettifyer code\n\n#                                                        │ │
# │ │               ------------------------------------------------------\nfrom'+575              │ │
# │ │         _i7 = 's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :       │ │
# │ │               99,\n}\n\n# Add'+98                                                            │ │
# │ │         _i8 = 's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :       │ │
# │ │               99,\n}\n\n# Add'+115                                                           │ │
# │ │         _i9 = 'from rich.console import Console\nconsole = Console()\n\ntry:\n               │ │
# │ │               do_something()\nex'+61                                                         │ │
# │ │         _ih = [                                                                              │ │
# │ │               │   '',                                                                        │ │
# │ │               │   '# Prettifyer code\n\n#                                                    │ │
# │ │               ------------------------------------------------------\nfrom'+575,             │ │
# │ │               │   's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :   │ │
# │ │               99,\n}',                                                                       │ │
# │ │               │   's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :   │ │
# │ │               99,\n}\n\n# Add'+32,                                                           │ │
# │ │               │   's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :   │ │
# │ │               99,\n}\n\n# Add'+45,                                                           │ │
# │ │               │   's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :   │ │
# │ │               99,\n}\n\n# Add'+64,                                                           │ │
# │ │               │   '# Prettifyer code\n\n#                                                    │ │
# │ │               ------------------------------------------------------\nfrom'+575,             │ │
# │ │               │   's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :   │ │
# │ │               99,\n}\n\n# Add'+98,                                                           │ │
# │ │               │   's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :   │ │
# │ │               99,\n}\n\n# Add'+115,                                                          │ │
# │ │               │   'from rich.console import Console\nconsole = Console()\n\ntry:\n           │ │
# │ │               do_something()\nex'+61                                                         │ │
# │ │               ]                                                                              │ │
# │ │         _ii = 's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :       │ │
# │ │               99,\n}\n\n# Add'+98                                                            │ │
# │ │        _iii = '# Prettifyer code\n\n#                                                        │ │
# │ │               ------------------------------------------------------\nfrom'+575              │ │
# │ │         _oh = {}                                                                             │ │
# │ │         box = <module 'rich.box' from '/opt/conda/lib/python3.10/site-packages/rich/box.py'> │ │
# │ │     Console = <class 'rich.console.Console'>                                                 │ │
# │ │     console = <console width=115 ColorSystem.TRUECOLOR>                                      │ │
# │ │        exit = <IPython.core.autocall.ZMQExitAutocall object at 0x79fe378df340>               │ │
# │ │ get_ipython = <bound method InteractiveShell.get_ipython of                                  │ │
# │ │               <ipykernel.zmqshell.ZMQInteractiveShell object at 0x79fe378de620>>             │ │
# │ │          In = [                                                                              │ │
# │ │               │   '',                                                                        │ │
# │ │               │   '# Prettifyer code\n\n#                                                    │ │
# │ │               ------------------------------------------------------\nfrom'+575,             │ │
# │ │               │   's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :   │ │
# │ │               99,\n}',                                                                       │ │
# │ │               │   's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :   │ │
# │ │               99,\n}\n\n# Add'+32,                                                           │ │
# │ │               │   's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :   │ │
# │ │               99,\n}\n\n# Add'+45,                                                           │ │
# │ │               │   's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :   │ │
# │ │               99,\n}\n\n# Add'+64,                                                           │ │
# │ │               │   '# Prettifyer code\n\n#                                                    │ │
# │ │               ------------------------------------------------------\nfrom'+575,             │ │
# │ │               │   's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :   │ │
# │ │               99,\n}\n\n# Add'+98,                                                           │ │
# │ │               │   's_s = {\n    "ina" : 91,\n    "ana" : 90,\n    "yin" : 80,\n    "fon" :   │ │
# │ │               99,\n}\n\n# Add'+115,                                                          │ │
# │ │               │   'from rich.console import Console\nconsole = Console()\n\ntry:\n           │ │
# │ │               do_something()\nex'+61                                                         │ │
# │ │               ]                                                                              │ │
# │ │     inspect = <function inspect at 0x79fe06823f40>                                           │ │
# │ │    Markdown = <class 'rich.markdown.Markdown'>                                               │ │
# │ │        open = <function open at 0x79fe38ab4820>                                              │ │
# │ │         Out = {}                                                                             │ │
# │ │       Panel = <class 'rich.panel.Panel'>                                                     │ │
# │ │      pprint = <function pprint at 0x79fe05de8550>                                            │ │
# │ │      Prompt = <class 'rich.prompt.Prompt'>                                                   │ │
# │ │        quit = <IPython.core.autocall.ZMQExitAutocall object at 0x79fe378df340>               │ │
# │ │      rprint = <function print at 0x79fe06823e20>                                             │ │
# │ │         s_s = {'ina': 91, 'ana': 90, 'yin': 80, 'fon': 99, 'pon': 100}                       │ │
# │ │       Style = <class 'rich.style.Style'>                                                     │ │
# │ │        Text = <class 'rich.text.Text'>                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'do_something' is not defined
