# %% [markdown]
# <h1 style="background-color:#020617; color:#db2777 ;padding:40px; text-align:center; text-shadow: 00 0 20px #ec4899">Section 1 Work</h1>
#
# > This will have all the work for this section and related notes
#
# 1. [`Colors`](https://rich.readthedocs.io/en/latest/appendix/colors.html?highlight=colors) _ list of standard colors that can be printed out

# %% [markdown]
# # TOC <a class="anchor"  id="toc"></a>
# - [6 - Printing to Console](#s6)
# - [8 - Coding Excercise - Printing](#s8)
# - [9 - String Manipulaiton & Code Intelligence](#s9)
# - [11 -  Python Inoyt Function](#s11)

# %% [markdown]
# Need to run prettifider code once before startin the actual work

# %%
# Prettifier 

# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
console = Console() # Standard code to access console
# -------------------------------------------------------

# %% [markdown]
# # Checkign the python version of this notebook

# %%
# Function to check python version 
import sys, pip

rprint("Python version: ", sys.version)
rprint("pip version: ", pip.__version__)
# Out:
# Python version:  3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# pip version:  23.3.2

# %% [markdown]
# ## [↩️TOC](#toc)
# ## 6 Printing in Python <a class="anchor"  id="s6"></a>
# 1. Recommended to use replit - Taling navigating in replit

# %% [markdown]
# > This section also has various print styles

# %%
print(f'Hello Panty')
pprint('Smell Pussy')

# Syntax Highlighting in lists 
rprint('hello Panty')

from rich import print
print("[bold red]alert![/bold red] Something happened")
print("[bold red]Bold and red[/] not bold or red")

print('''
Whattup
''')

# With import you can add color 
console.rule("[bold magenta]Chapter 2")
console.print("""
              Centered Text - mistress fart
              in mouth and nose
              """, style="bold red", justify="center")


# Printing Panel
panel = Panel("""
Enjoy StinlySmellySWeaty women
""",title="Mistress",subtitle="ToiletSlave", style="Italic", border_style="magenta")
# Print the Panel
console.print(panel)
# Out:
# Hello Panty
# 'Smell Pussy'
# hello Panty
# alert! Something happened
# Bold and red not bold or red
# Whattup
# ──────────────────────────────────────────────────── Chapter 2 ────────────────────────────────────────────────────
#
#                                                   Centered Text - mistress fart
#                                                         in mouth and nose
# ╭─────────────────────────────────────────────────── Mistress ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Enjoy StinlySmellySWeaty women                                                                                  │
# │                                                                                                                 │
# ╰────────────────────────────────────────────────── ToiletSlave ──────────────────────────────────────────────────╯

# %%
# This with print imported from rich
print('''
[green]T[red]est
''')

# rprint method
rprint('''
Test
''')

# pprint method
pprint('''
Sniff
''')
# Out:
# Test
# Test
# '\nSniff\n'

# %% [markdown]
# Opt to import print as
#
# ```py
# from rich import print as rprint # For rprinting
# ```
#
# - This way you can still have access to the CLI print

# %% [markdown]
# ## [↩️TOC](#toc)
#
# ## 8 Printing in Python <a class="anchor"  id="s8"></a>
#
# 1. Note even # codes for colors work

# %%
# Solution 

rprint('''
[green] 1. She moves forward.
[magenta] 2. Her \"pussy\" slides above my nose.
[yellow] 3. Her asshole comes resting neatly on my lips.
[#ff00ff] 4. A "fart" quickly travels past the entrance of my waiting mouth.
''')
# Out:
#  1. She moves forward.
#  2. Her "pussy" slides above my nose.
#  3. Her asshole comes resting neatly on my lips.
#  4. A "fart" quickly travels past the entrance of my waiting mouth.

# %% [markdown]
# ## [↩️TOC](#toc)
#
# ## 9 -  String Manipulation and Code Intelligence <a class="anchor"  id="s9"></a>
#
# - Code intelligence is referrign to auto completion

# %%
# Printing in new line 
print('\n Suck and \nfuck\n')

# Concat String 
print('Ass' + "  " + ' Pussy')
# Out:
#  Suck and
# fuck
# Ass   Pussy

# %% [markdown]
# ## [↩️TOC](#toc)
#
# ## 11 -  Python Input Function <a class="anchor"  id="s11"></a>
#
# 1. Section talks about python input function you wil use rich version

# %%
# Standard Input function - Using Literals

myData = input('whatup')
rprint(f'''
Your Entered: [green] {myData}
''')
# Out:
# whatup 23
# Your Entered:  23

# %%
# Using the same with  prompt 
name = Prompt.ask("Enter your name", default="Paul Atreides")
rprint(f'What name u? : [#22d3ee]{name}')
# Out:
# Enter your name (Paul Atreides):
#  Dangona
# What name u? : Dangona

# %%
# Writing in one line 

rprint('''
What is the time
''' + Prompt.ask('Write time bastard', default='69'))
# Out:
# Write time bastard (69):
# What is the time
# 69
