# %% [markdown]
# <div style="background: url(https://i.giphy.com/26n6CWImwECKu3fy0.webp) repeat; color: #00ff00; padding: 2px; text-align: center;background-size: cover; text-shadow: 00 0 20px #ec4899">
#     <h1>Section 6 Work - Python Functions and Karel</h1>
#
# </div>
#
# 1. [`Colors`](https://rich.readthedocs.io/en/latest/appendix/colors.html?highlight=colors) _ list of standard colors that can be printed out
# 2. [`Ascii Banne Generator`](https://manytools.org/hacker-tools/ascii-banner/https://manytools.org/hacker-tools/ascii-banner/) - Used this to generate nice banners below
# 3. [`AsciiFlow`](https://asciiflow.com/#/https://asciiflow.com/#/) - Draw ASCII digrams you can then use this

# %% [markdown]
# <div style="background-color: #000502; color: #16a34a; padding: 10px; border-radius: 5px; font-size: 25px; text-align:center">
#   <a class="anchor" id="toc" style="text-decoration: none;">Table of Contents</a>
# </div>
#
#
# - ### [61 - Defining and Calling Functions](#s61)
# - ### [62 - While Loops](#s62)

# %%
# Prettifyer code

# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
from rich.style import Style # For styles colors
from rich.text import Text # For text Styles
console = Console() # Standard code to access console
# -------------------------------------------------------

# %% [markdown]
# ## 61 - Defining and Calling Functions <a class="anchor" id="s61"></a> [↩️TOC](#toc)

# %%
# Typing function 
num_char = len('Panty Smell')
rprint(num_char)
# Out:
# 11

# %%
# Defining my function 
def my_fu():
    """
    This function for panty sniffing
    """
    rprint(f'''
    [magenta1]
,ggggggggggg,                                              
dP"""88""""""Y8,                            I8              
Yb,  88      `8b                            I8              
 `"  88      ,8P                         88888888           
     88aaaad8P"                             I8              
     88""""Y8ba    ,ggggg,      ,ggggg,     I8    gg     gg 
     88      `8b  dP"  "Y8ggg  dP"  "Y8ggg  I8    I8     8I 
     88      ,8P i8'    ,8I   i8'    ,8I   ,I8,   I8,   ,8I 
     88_____,d8',d8,   ,d8'  ,d8,   ,d8'  ,d88b, ,d8b, ,d8I 
    88888888P"  P"Y8888P"    P"Y8888P"   88P""Y88P""Y88P"888
                                                       ,d8I'
                                                     ,dP'8I 
                                                    ,8"  8I 
                                                    I8   8I 
                                                    `8, ,8I 
                                                     `Y8P"  
    ''')
    
####################

# Executing the function    
my_fu()
# Out:
#
# ,ggggggggggg,
# dP"""88""""""Y8,                            I8
# Yb,  88      `8b                            I8
#  `"  88      ,8P                         88888888
#      88aaaad8P"                             I8
#      88""""Y8ba    ,ggggg,      ,ggggg,     I8    gg     gg
#      88      `8b  dP"  "Y8ggg  dP"  "Y8ggg  I8    I8     8I
#      88      ,8P i8'    ,8I   i8'    ,8I   ,I8,   I8,   ,8I
#      88_____,d8',d8,   ,d8'  ,d8,   ,d8'  ,d88b, ,d8b, ,d8I
#     88888888P"  P"Y8888P"    P"Y8888P"   88P""Y88P""Y88P"888
#                                                        ,d8I'
#                                                      ,dP'8I
#                                                     ,8"  8I
#                                                     I8   8I
#                                                     `8, ,8I
#                                                      `Y8P"

# %% [markdown]
# 1, Talks about karel the robot , not sure what ?
#
# [`Reeborg Work`](https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=%2Fworlds%2Fmenus%2Fselect_collection_en.json&name=Other%20worlds&url=%2Fworlds%2Fmenus%2Fselect_collection_en.json)
# - Website for learning about funtions

# %% [markdown]
# Writing a simple function that makes that game

# %%
# Print Left 
def Lefat():
    rprint(f'[#00ff00]⬅️⬅️⬅️⬅️')

# Print Right 
def Righat():
    rprint(f'[#00ff00]▶️▶️▶️▶️')
    
# Call functions 
Lefat()
Righat()

# Make nested function 

def LeRa():
    '''
    This combines the above 2 functions
    '''
    Lefat()
    Righat()

# Call the above function 
LeRa()
# Out:
# ⬅️⬅️⬅️⬅️
# ▶️▶️▶️▶️
# ⬅️⬅️⬅️⬅️
# ▶️▶️▶️▶️

# %% [markdown]
# ## 62 - While Loops <a class="anchor" id="s62"></a> [↩️TOC](#toc)

# %%
# Writing and testing the while loops
